# %%
# %ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 6010-3509
#
#  Directory of C:\Users\amitm\EWS_project\EWSofInfectousDiseases-Codes\Trained_DL_models_and_testing\test_models_simulations_and_empirical_data
#
# 2023-12-07  03:43 PM    <DIR>          .
# 2023-12-06  09:01 PM    <DIR>          ..
# 2023-12-06  08:07 PM    <DIR>          .ipynb_checkpoints
# 2023-12-07  03:43 PM             2,447 check.ipynb
# 2023-12-06  08:05 PM             1,572 effective_rep_no_EpiEstim.R
# 2023-12-07  01:28 AM            10,769 test_simulations_DemNoise.py
# 2023-12-07  01:28 AM            10,528 test_simulations_EnvNoise.py
# 2023-12-07  01:28 AM            12,080 test_simulations_SEIR.py
# 2023-12-07  01:28 AM            10,448 test_simulations_WhiteNoise.py
# 2023-12-06  11:12 PM             4,860 test-simulations-empirical-Flu.py
#                7 File(s)         52,704 bytes
#                3 Dir(s)  346,508,959,744 bytes free

# %%
# %run C:\Users\amitm\EWS_project\EWSofInfectousDiseases-Codes\Trained_DL_models_and_testing\test_models_simulations_and_empirical_data/test_simulations_SEIR.py
# Out:
# betabif= 0.018046875
# beta_intercept= [0.00536602 0.00480893 0.00392775 0.00231412 0.00510142 0.00339144
#  0.00617909 0.0037442  0.00245811 0.00462213 0.00448958 0.00304633
#  0.00310873 0.00369219 0.00300887 0.0041953  0.00819904 0.00339505
#  0.0016695  0.00445039]
# beta_slope= [5.730657049834026e-06, 4.4461708835036545e-06, 6.070234294810606e-06, 3.2049235719801603e-06, 2.3196372675050387e-06, 6.096486078740504e-06, 4.095409126220832e-06, 6.894869555081847e-06, 7.220475646373347e-06, 3.87273237135075e-06, 1.2838745880095143e-05, 1.4889792254038968e-05, 1.706863373716544e-05, 1.4768696939076259e-05, 1.735042262919167e-05, 1.790226538703064e-05, 1.573422145654135e-05, 1.2554693852090916e-05, 1.3884445258958059e-05, 1.6130769465158944e-05]
#
# Begin simulations
#
# Simulation 1 complete
# Simulation 2 complete
# Simulation 3 complete
# Simulation 4 complete
# Simulation 5 complete
# Simulation 6 complete
# Simulation 7 complete
# Simulation 8 complete
# Simulation 9 complete
# ...
